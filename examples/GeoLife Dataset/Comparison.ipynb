# %% [markdown]
# # GeoLife

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import math
import glob
from datetime import datetime

# %%
df = pd.read_csv("data/GeoLife_prepared.zip")

df = df[df.tid < df.tid.max()*.2] #prendo il 20% del dataset

df0 = df[["tid", "label", "lat", "lon", "time"]].rename(columns={
    "label": "class", "lat": "c1", "lon": "c2", "time": "t"})

df0.head()
# Out:
#    tid  class         c1          c2             t
# 0    0  train  39.894178  116.318200  1.206716e+09
# 1    0  train  39.894505  116.321132  1.206716e+09
# 2    0  train  39.894953  116.326452  1.206716e+09
# 3    0  train  39.894600  116.332542  1.206716e+09
# 4    0  train  39.889622  116.337040  1.206716e+09

# %%
remap_class = {
    "subway": "public",
    "motorcycle": "private",
    "run": "private",
    "walk": "private",
    "boat": "private",
    "airplane": "public",
    "train": "public",
    "car": "private",
    "taxi": "public",
    "bike": "private",
    "bus": "public"
}

# %%
df0["class"] = df0["class"].apply(lambda x: remap_class[x])

# %%
df0["class"].unique()
# Out:
# array(['public', 'private'], dtype=object)

# %% [markdown]
# ## Rocket

# %%
t_rocket = 0

start = datetime.now()

df0["pos"] = df0.groupby(['tid']).cumcount()

df0 = df0[df0.pos < df0.pos.quantile(.9)]

t_rocket = (datetime.now() - start).total_seconds() * 1000 #ms

# %%
df0.describe().pos.apply(lambda x: int(x))
# Out:
# count    1410006
# mean        3540
# std         4581
# min            0
# 25%          403
# 50%         1423
# 75%         4917
# max        19346
# Name: pos, dtype: int64

# %%
df0.pos.quantile(.9)
# Out:
# 10833.0

# %%
start = datetime.now()


def padLastValue(df):
    array = df.values
    for i in tqdm(range(len(array))):
        for j in range(len(array[i])):
            if math.isnan(array[i][j]):
                array[i][j] =array[i][j-1]
    return pd.DataFrame(array)

print("LAT")
df_lat = pd.DataFrame()
df_lat = df0.groupby(['tid','pos'])['c1'].max().unstack()
df_lat = padLastValue(df_lat)

print("LON")
df_lon = pd.DataFrame()
df_lon = df0.groupby(['tid','pos'])['c2'].max().unstack()
df_lon = padLastValue(df_lon)

print("TIME")
df_time = pd.DataFrame()
df_time = df0.groupby(['tid','pos'])['t'].max().unstack()
df_time = padLastValue(df_time)

t_rocket = (datetime.now() - start).total_seconds() * 1000 #ms
# Out:
# LAT
#   0%|          | 0/1196 [00:00<?, ?it/s]
# LON
#   0%|          | 0/1196 [00:00<?, ?it/s]
# TIME
#   0%|          | 0/1196 [00:00<?, ?it/s]

# %%
start = datetime.now()

from sktime.transformations.panel.rocket import Rocket
from sktime.datatypes._panel._convert import from_2d_array_to_nested

nested_lat = from_2d_array_to_nested(df_lat).rename(columns={0: "dim_0"})
nested_lon = from_2d_array_to_nested(df_lon).rename(columns={0: "dim_0"})
nested_time = from_2d_array_to_nested(df_time).rename(columns={0: "dim_0"})


nested = nested_lat
#nested = nested_UTMGridNorth

nested["dim_1"] = nested_lon["dim_0"]
nested["dim_2"] = nested_time["dim_0"]

nested.head()

y = df0.groupby(['tid'])['class'].max()

t_rocket = (datetime.now() - start).total_seconds() * 1000 #ms
# Out:
# C:\Users\cri98\anaconda3\lib\site-packages\sktime\datatypes\_series\_check.py:43: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)
# C:\Users\cri98\anaconda3\lib\site-packages\sktime\datatypes\_hierarchical\_check.py:50: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)
# C:\Users\cri98\anaconda3\lib\site-packages\sktime\datatypes\_hierarchical\_check.py:51: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_MULTIINDEX_TYPES = (pd.Int64Index, pd.RangeIndex)
# C:\Users\cri98\anaconda3\lib\site-packages\sktime\datatypes\_panel\_check.py:48: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)
# C:\Users\cri98\anaconda3\lib\site-packages\sktime\datatypes\_panel\_check.py:49: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_MULTIINDEX_TYPES = (pd.Int64Index, pd.RangeIndex)
# C:\Users\cri98\anaconda3\lib\site-packages\sktime\datatypes\_proba\_check.py:43: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)

# %%
start = datetime.now()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(nested, y, test_size=.3, stratify=y)

rocket = Rocket(n_jobs=-1, num_kernels=10000)  # by default, ROCKET uses 10,000 kernels
rocket.fit(X_train)
X_train_transform = rocket.transform(X_train)
X_test_transform = rocket.transform(X_test)

t_rocket = (datetime.now() - start).total_seconds() * 1000 #ms

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                results['mean_test_score'][candidate],
                results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

from sklearn.model_selection import GridSearchCV
parameters = {'n_estimators': range(300, 1500, 300),
              'criterion':["entropy", "gini"],
              'max_depth': range(2, 20, 5)}

clf = GridSearchCV(RandomForestClassifier(n_jobs=1), parameters, cv=10, n_jobs=24, verbose=3, scoring="balanced_accuracy")

clf.fit(X_train_transform, y_train)

report(clf.cv_results_, n_top=3)
# Out:
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# Model with rank: 1
# Mean validation score: 0.745 (std: 0.054)
# Parameters: {'criterion': 'gini', 'max_depth': 17, 'n_estimators': 600}
#
# Model with rank: 2
# Mean validation score: 0.743 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 17, 'n_estimators': 900}
#
# Model with rank: 3
# Mean validation score: 0.742 (std: 0.050)
# Parameters: {'criterion': 'entropy', 'max_depth': 12, 'n_estimators': 1200}

# %%
clf = RandomForestClassifier(max_depth=12, criterion='entropy', random_state=5, n_jobs=-1, n_estimators=900)
#clf = tree.DecisionTreeClassifier(max_depth=2)

clf.fit(X_train_transform, y_train)

from sklearn import metrics
y_pred=clf.predict(X_test_transform)


from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      private       0.71      0.76      0.73       173
#       public       0.76      0.71      0.73       186
#
#     accuracy                           0.73       359
#    macro avg       0.73      0.73      0.73       359
# weighted avg       0.73      0.73      0.73       359

# %%
from sklearn.metrics import accuracy_score, f1_score

print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average="weighted"))
# Out:
# 0.7325905292479109
# 0.7326154277088746

# %%
t_rocket
# Out:
# 508471.023

# %% [markdown]
# ## Movelets

# %%
import random
import os


def prepareForShapelet(df=pd.DataFrame, trajectoryIDAttribute= None, targetAttribute=None,
                       timestampAttribute=None, latAttr=None, lonAttr=None, trainPerc=.80, trajPerc=1.0, maxPoints=None):
    attributes = [timestampAttribute, "latLon"]+ [x for x in list(df.columns) if x not in [trajectoryIDAttribute, targetAttribute, timestampAttribute, latAttr, lonAttr]] #mi assicuro di avere il timestam come primo elemento
    if(os.path.exists("train") | os.path.exists("test")):
        print("Le cartelle train e test esistono già!")
        return

    df["latLon"] = df[latAttr].astype(str) + " " + df[lonAttr].astype(str)

    ids = list(df[trajectoryIDAttribute].unique())
    #ids = random.sample(ids, round(len(ids)*trajPerc))
    ids = ids[:round(len(ids)*trajPerc)]
    ids_train = random.sample(ids, round(trainPerc*len(ids)))
    ids_test = [x for x in ids if x not in ids_train]

    os.makedirs("train")
    os.makedirs("test")

    for id in tqdm(ids_train):
        df_id = df[df[trajectoryIDAttribute] == id]
        classe = df_id[targetAttribute].iloc[0]
        if maxPoints is not None:
            df[df[trajectoryIDAttribute] == id][attributes].head(maxPoints).to_csv(F"train/{id} s{id} c{classe}.r2", index=False, header=False)
        else:
            df[df[trajectoryIDAttribute] == id][attributes].to_csv(F"train/{id} s{id} c{classe}.r2", index=False, header=False)

    for id in tqdm(ids_test):
        df_id = df[df[trajectoryIDAttribute] == id]
        if maxPoints is not None:
            df_id = df_id.head(maxPoints)
        classe = df_id[targetAttribute].iloc[0]
        if maxPoints is not None:
            df[df[trajectoryIDAttribute] == id][attributes].head(maxPoints).to_csv(F"test/{id} s{id} c{classe}.r2", index=False, header=False)
        else:
            df[df[trajectoryIDAttribute] == id][attributes].to_csv(F"test/{id} s{id} c{classe}.r2", index=False, header=False)

prepareForShapelet(df0, "tid", "class", "t", "c1", "c2", trainPerc=.7, trajPerc=1)
# Out:
#   0%|          | 0/837 [00:00<?, ?it/s]
#   0%|          | 0/359 [00:00<?, ?it/s]

# %%
# 25733s

# %%
movelet_train_df = pd.read_csv("data/Movelet_output/train.csv")
movelet_test_df = pd.read_csv("data/Movelet_output/test.csv")

movelet_train_df.head()
# Out:
#    sh_TID69_START24_SIZE2_CLASSC  sh_TID98_START110_SIZE2_CLASSC  \
# 0                       1.588584                        1.649389
# 1                       0.969382                        0.474057
# 2                       0.775535                        0.922867
# 3                       1.244408                        1.323665
# 4                       1.610240                        1.665120
#
#    sh_TID80_START23_SIZE1_CLASSC  sh_TID75_START90_SIZE2_CLASSC  \
# 0                       1.576020                       1.611770
# 1                       0.896539                       0.629428
# 2                       0.539484                       0.853516
# 3                       1.240741                       1.283351
# 4                       1.605926                       1.629457
#
#    sh_TID13_START140_SIZE13_CLASSE  sh_TID13_START7_SIZE132_CLASSE  \
# 0                         0.272882                   3.028427e-310
# 1                         1.840714                   7.079885e-310
# 2                         1.671193                   7.079885e-310
# 3                         0.998760                   4.977281e-310
# 4                         0.287881                   2.273328e-310
#
#    sh_TID98_START118_SIZE2_CLASSC  sh_TID88_START99_SIZE2_CLASSC class
# 0                        1.588081                       1.597207     D
# 1                        0.994866                       0.711483     C
# 2                        0.777712                       0.751979     C
# 3                        1.249638                       1.248647     D
# 4                        1.609066                       1.618398     E

# %%
movelet_test_df.head()
# Out:
#    sh_TID69_START24_SIZE2_CLASSC  sh_TID98_START110_SIZE2_CLASSC  \
# 0                       1.805489                        1.836301
# 1                       1.127098                        0.269020
# 2                       1.223616                        1.304504
# 3                       1.233781                        1.305168
# 4                       1.135216                        0.981418
#
#    sh_TID80_START23_SIZE1_CLASSC  sh_TID75_START90_SIZE2_CLASSC  \
# 0                       1.808063                       1.817643
# 1                       1.138115                       0.541418
# 2                       1.191131                       1.263482
# 3                       1.181491                       1.271689
# 4                       0.840591                       1.174660
#
#    sh_TID13_START140_SIZE13_CLASSE  sh_TID13_START7_SIZE132_CLASSE  \
# 0                         0.323427                   4.473884e-310
# 1                         1.845579                   7.079885e-310
# 2                         0.993015                   5.586640e-310
# 3                         1.660812                   7.079885e-310
# 4                         1.756175                   7.079885e-310
#
#    sh_TID98_START118_SIZE2_CLASSC  sh_TID88_START99_SIZE2_CLASSC class
# 0                        1.805202                       1.809469     E
# 1                        1.133103                       0.753968     C
# 2                        1.228602                       1.226847     D
# 3                        1.239996                       1.234993     D
# 4                        1.140020                       0.989248     D

# %%
# Out:
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.714 total time=   0.5s
# [CV 8/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 8/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.714 total time=   0.9s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.556 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.556 total time=   1.3s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.667 total time=   1.8s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.667 total time=   1.9s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.667 total time=   0.5s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.444 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.667 total time=   1.7s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.556 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.556 total time=   0.4s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 9/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.857 total time=   1.2s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 1/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.875 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.625 total time=   1.4s
# [CV 5/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.875 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 9/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.9s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.875 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=1.000 total time=   1.4s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 10/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.571 total time=   1.1s
# [CV 5/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.667 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.556 total time=   1.3s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.722 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.500 total time=   0.5s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.722 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.556 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.500 total time=   0.4s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.722 total time=   1.9s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.667 total time=   1.8s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.667 total time=   1.7s
# [CV 6/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.833 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.556 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.875 total time=   1.8s
# [CV 1/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.750 total time=   1.8s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.714 total time=   1.2s
# [CV 1/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 8/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 5/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.750 total time=   1.8s
# [CV 9/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 8/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.9s
# [CV 5/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=1.000 total time=   1.7s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.857 total time=   1.0s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.857 total time=   0.5s
# [CV 2/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 10/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.857 total time=   1.4s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 5/10] END criterion=gini, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 2/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.571 total time=   1.4s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.722 total time=   0.5s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.667 total time=   0.5s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.500 total time=   1.3s
# [CV 6/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.722 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.667 total time=   1.8s
# [CV 2/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.500 total time=   1.7s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.667 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.556 total time=   0.9s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.500 total time=   0.5s
# [CV 7/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=12, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 10/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.556 total time=   1.7s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.2s
# [CV 5/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.714 total time=   0.5s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=1.000 total time=   1.4s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.875 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 2/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.875 total time=   0.8s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 6/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.5s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 2/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 10/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 1/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.875 total time=   1.3s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.857 total time=   1.0s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.714 total time=   0.5s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 3/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 6/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.875 total time=   0.4s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.9s
# [CV 10/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 6/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.4s
# [CV 1/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.667 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.833 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.667 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.556 total time=   1.4s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.667 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.611 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 6/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.722 total time=   1.8s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.6s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.875 total time=   0.5s
# [CV 5/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 8/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 7/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 3/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.4s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.750 total time=   0.5s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 2/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 7/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 8/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.625 total time=   0.9s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.4s
# [CV 2/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.500 total time=   1.3s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.722 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.722 total time=   0.9s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.556 total time=   1.8s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.722 total time=   0.5s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.667 total time=   1.4s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.667 total time=   1.4s
# [CV 2/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.500 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.833 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.667 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.667 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.722 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 8/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 8/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.875 total time=   0.9s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=900;, score=1.000 total time=   1.2s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.875 total time=   1.8s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.875 total time=   1.9s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.5s
# [CV 2/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 2/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.500 total time=   0.5s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.667 total time=   1.7s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.833 total time=   1.4s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.500 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.556 total time=   1.4s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.556 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.722 total time=   0.9s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.722 total time=   1.1s
# [CV 6/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.750 total time=   1.7s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.2s
# [CV 7/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 8/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.857 total time=   1.1s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=1.000 total time=   1.7s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.714 total time=   1.2s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.857 total time=   1.9s
# [CV 3/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.875 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.857 total time=   1.4s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 9/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.857 total time=   1.7s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=1.000 total time=   1.7s
# [CV 10/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 5/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.875 total time=   1.8s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.750 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 6/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.3s
# [CV 6/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.556 total time=   1.7s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.667 total time=   1.8s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.722 total time=   1.9s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.667 total time=   0.5s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.667 total time=   0.6s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.556 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.722 total time=   0.5s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.667 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.722 total time=   1.8s
# [CV 4/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.667 total time=   1.8s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.722 total time=   1.2s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.750 total time=   0.5s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.571 total time=   1.4s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.857 total time=   1.4s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 8/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.625 total time=   0.5s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 4/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 2/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.571 total time=   1.6s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.750 total time=   1.3s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 3/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=1.000 total time=   1.9s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.750 total time=   1.5s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.875 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.714 total time=   0.5s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.9s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.571 total time=   1.7s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.750 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=1.000 total time=   1.0s
# [CV 2/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.750 total time=   1.7s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.667 total time=   0.4s
# [CV 5/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.667 total time=   1.4s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.667 total time=   1.3s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.833 total time=   0.5s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.556 total time=   0.9s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.722 total time=   0.4s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.833 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.833 total time=   1.8s
# [CV 9/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.556 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.500 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.667 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.722 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.667 total time=   0.4s
# ...
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 6/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.571 total time=   1.4s
# [CV 2/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 10/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 10/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 7/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.750 total time=   1.3s
# [CV 9/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=12, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.857 total time=   1.7s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.5s
# [CV 8/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 5/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.9s
# [CV 9/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 1/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.750 total time=   1.8s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.714 total time=   1.2s
# [CV 4/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.556 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.667 total time=   1.7s
# [CV 1/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.667 total time=   1.8s
# [CV 9/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.667 total time=   1.4s
# [CV 3/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.667 total time=   0.7s
# [CV 5/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.667 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=7, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.833 total time=   1.8s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.500 total time=   1.9s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.667 total time=   1.5s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 8/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.571 total time=   0.4s
# [CV 7/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 8/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 10/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 7/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 3/10] END criterion=gini, max_depth=17, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.2s
# [CV 8/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 1/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.857 total time=   1.4s
# [CV 3/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 8/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.750 total time=   0.5s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.857 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.714 total time=   1.1s
# [CV 5/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 8/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 3/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.875 total time=   0.9s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 4/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 8/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.571 total time=   1.6s
# [CV 7/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.571 total time=   1.0s
# [CV 4/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 1/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.857 total time=   1.4s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 2/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.714 total time=   1.4s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 1/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.750 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=7, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 2/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.571 total time=   1.8s
# [CV 1/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.875 total time=   1.4s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.556 total time=   0.9s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.500 total time=   0.5s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.556 total time=   0.5s
# [CV 3/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=1.000 total time=   1.4s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.833 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.722 total time=   0.9s
# [CV 9/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.667 total time=   2.0s
# [CV 4/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.667 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.833 total time=   0.9s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=1200;, score=0.556 total time=   1.7s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=1.000 total time=   1.8s
# [CV 8/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.722 total time=   1.1s
# [CV 10/10] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 8/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 5/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=7, n_estimators=1200;, score=0.714 total time=   1.7s
# [CV 1/10] END criterion=entropy, max_depth=12, n_estimators=1200;, score=0.875 total time=   1.7s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=900;, score=0.750 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=7, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 9/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 3/10] END criterion=gini, max_depth=12, n_estimators=300;, score=1.000 total time=   0.4s
# [CV 7/10] END criterion=gini, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 5/10] END criterion=gini, max_depth=12, n_estimators=600;, score=1.000 total time=   0.9s
# [CV 9/10] END criterion=gini, max_depth=12, n_estimators=1200;, score=0.857 total time=   1.7s
# [CV 5/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=1.000 total time=   1.4s
# [CV 1/10] END criterion=entropy, max_depth=2, n_estimators=900;, score=0.750 total time=   1.4s
# [CV 2/10] END criterion=entropy, max_depth=7, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 10/10] END criterion=entropy, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 4/10] END criterion=entropy, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.750 total time=   0.9s
# [CV 5/10] END criterion=entropy, max_depth=17, n_estimators=900;, score=1.000 total time=   1.3s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 7/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.429 total time=   1.7s
# [CV 9/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.857 total time=   1.4s
# [CV 4/10] END criterion=gini, max_depth=12, n_estimators=900;, score=0.571 total time=   1.3s
# [CV 2/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 6/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.857 total time=   1.3s
# [CV 3/10] END criterion=entropy, max_depth=2, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 6/10] END criterion=entropy, max_depth=2, n_estimators=1200;, score=0.714 total time=   1.8s
# [CV 2/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 10/10] END criterion=entropy, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 1/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.750 total time=   0.5s
# [CV 8/10] END criterion=entropy, max_depth=17, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 4/10] END criterion=entropy, max_depth=17, n_estimators=600;, score=0.571 total time=   0.9s
# [CV 7/10] END criterion=entropy, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.8s
# [CV 1/10] END criterion=gini, max_depth=2, n_estimators=1200;, score=0.750 total time=   1.7s
# [CV 7/10] END criterion=gini, max_depth=7, n_estimators=900;, score=0.714 total time=   1.3s
# [CV 10/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 4/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.571 total time=   0.5s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=300;, score=0.857 total time=   0.4s
# [CV 6/10] END criterion=gini, max_depth=17, n_estimators=600;, score=0.714 total time=   0.9s
# [CV 9/10] END criterion=gini, max_depth=17, n_estimators=1200;, score=0.857 total time=   1.6s

# %%
X_train = movelet_train_df.values[:, :-1]
y_train = movelet_train_df.values[:, -1]

X_test = movelet_test_df.values[:, :-1]
y_test = movelet_test_df.values[:, -1]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                results['mean_test_score'][candidate],
                results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

from sklearn.model_selection import GridSearchCV
parameters = {'n_estimators': range(300, 1500, 300),
              'criterion':["entropy", "gini"],
              'max_depth': range(2, 20, 5)}

clf = GridSearchCV(RandomForestClassifier(n_jobs=1), parameters, cv=3, n_jobs=24, verbose=3, scoring="accuracy")

clf.fit(X_train, y_train)

report(clf.cv_results_, n_top=3)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Model with rank: 1
# Mean validation score: 0.747 (std: 0.030)
# Parameters: {'criterion': 'entropy', 'max_depth': 17, 'n_estimators': 600}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 7, 'n_estimators': 900}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 12, 'n_estimators': 300}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 12, 'n_estimators': 600}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 12, 'n_estimators': 900}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 12, 'n_estimators': 1200}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 17, 'n_estimators': 300}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'entropy', 'max_depth': 17, 'n_estimators': 900}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'gini', 'max_depth': 7, 'n_estimators': 300}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'gini', 'max_depth': 7, 'n_estimators': 900}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'gini', 'max_depth': 12, 'n_estimators': 900}
#
# Model with rank: 2
# Mean validation score: 0.733 (std: 0.049)
# Parameters: {'criterion': 'gini', 'max_depth': 17, 'n_estimators': 1200}

# %%
#rf = RandomForestClassifier(max_depth=7, random_state=3, n_jobs=-1, n_estimators=300, criterion="entropy")
rf = clf.best_estimator_

rf.fit(X_train, y_train)

from sklearn import metrics
y_pred=rf.predict(X_test)


from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.67      0.89      0.76         9
#            D       0.50      0.25      0.33        12
#            E       0.38      0.50      0.43        10
#
#     accuracy                           0.52        31
#    macro avg       0.52      0.55      0.51        31
# weighted avg       0.51      0.52      0.49        31

# %%
clf.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=7, n_estimators=300,
#                        n_jobs=1)

# %%
rf = clf.best_estimator_
#clf = tree.DecisionTreeClassifier(max_depth=2)

rf.fit(X_test, y_test)

from sklearn import metrics
y_pred=rf.predict(X_train)


from sklearn.metrics import classification_report

print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.95      0.76      0.84        25
#            D       0.35      0.39      0.37        18
#            E       0.45      0.50      0.47        28
#
#     accuracy                           0.56        71
#    macro avg       0.58      0.55      0.56        71
# weighted avg       0.60      0.56      0.58        71

# %% [markdown]
# ## Geolet

# %%
from cri98tj.distancers.Euclidean_distancer import Euclidean_distancer
from cri98tj.distancers.InterpolatedRootDistance_distancer import InterpolatedRootDistance_distancer, \
    InterpolatedRootDistanceBestFitting
from cri98tj.normalizers.FirstPoint_normalizer import FirstPoint_normalizer
from cri98tj.normalizers.normalizer_utils import dataframe_pivot
from cri98tj.partitioners.Geohash_partitioner import Geohash_partitioner
from cri98tj.selectors.RandomInformationGain_selector import RandomInformationGain_selector
from cri98tj.selectors.Random_selector import Random_selector
from cri98tj.selectors.RandomOrderline_selector import RandomOrderline_selector
from cri98tj.TrajectoryTransformer import TrajectoryTransformer
from sklearn.ensemble import RandomForestClassifier
# Out:
# c:\users\cri98\documents\github\cri98tj\cri98tj\distancers\Euclidean_distancer.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
df_geo = df0[["tid", "class", "c1", "c2", "t"]].copy()

df_geo.head()
# Out:
#    tid   class         c1          c2             t
# 0    0  public  39.894178  116.318200  1.206716e+09
# 1    0  public  39.894505  116.321132  1.206716e+09
# 2    0  public  39.894953  116.326452  1.206716e+09
# 3    0  public  39.894600  116.332542  1.206716e+09
# 4    0  public  39.889622  116.337040  1.206716e+09

# %%
# %%time

from sklearn.model_selection import train_test_split

spatioTemporalCols = ["c1", "c2", "t"]
tid_train, tid_test, _, _ = train_test_split(df_geo.groupby(by=["tid"]).max().reset_index()["tid"],
                                                            df_geo.groupby(by=["tid"]).max().reset_index()["class"],
                                                            test_size=.3,
                                                            stratify=df_geo.groupby(by=["tid"]).max().reset_index()["class"],
                                                            random_state=3)

partitioner = Geohash_partitioner(precision=6, spatioTemporalColumns=spatioTemporalCols)


normalizer = FirstPoint_normalizer(spatioTemporalColumns=spatioTemporalCols, fillna=None)
#selector = Random_selector(movelets_per_class=20, normalizer=normalizer,
#                                   spatioTemporalColumns=spatioTemporalCols)
selector = RandomInformationGain_selector(top_k=50, bestFittingMeasure=InterpolatedRootDistanceBestFitting,
                                                  movelets_per_class=100, trajectories_for_orderline=50, n_jobs=24,
                                                  spatioTemporalColumns=spatioTemporalCols, normalizer=normalizer)
distancer = InterpolatedRootDistance_distancer(normalizer=normalizer, spatioTemporalColumns=spatioTemporalCols, n_jobs=24)

part = partitioner.fit_transform(df_geo[df_geo.tid.isin(tid_train)].values)
shapelets = selector.fit_transform(part)
best_is, dist_np = distancer.fit_transform((df_geo.values, shapelets))
# Out:
# Encoding 1048162 points with precision 6
#   0%|          | 0/1048162 [00:00<?, ?it/s]
# Cutting sub-trajectories length at 1360.0 over 1617
# Pivoting tables
#   0%|          | 0/9562 [00:00<?, ?it/s]
# Cutting sub-trajectories length at 22631.949999999997 over 26136
# Pivoting tables
#   0%|          | 0/66577 [00:00<?, ?it/s]
# Computing scores
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# C:\Users\cri98\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.	 score=0.35278851224110985
# 1.	 score=0.3258777563303539
# 2.	 score=0.30231977629868956
# 3.	 score=0.3001740670028257
# 4.	 score=0.23007355640231486
# 5.	 score=0.21546884944776257
# 6.	 score=0.20478834161710036
# 7.	 score=0.20254181037056918
# 8.	 score=0.19195654596177514
# 9.	 score=0.1814505519557812
# 10.	 score=0.1742702485990073
# 11.	 score=0.17408748691624587
# 12.	 score=0.17384026398094177
# 13.	 score=0.16631065263941092
# 14.	 score=0.15762522695398506
# 15.	 score=0.15566635249511096
# 16.	 score=0.150050246379005
# 17.	 score=0.13306749873449242
# 18.	 score=0.1284361937649523
# 19.	 score=0.12648958481834338
# 20.	 score=0.1214280352567938
# 21.	 score=0.11884289817165672
# 22.	 score=0.11594772961472355
# 23.	 score=0.11540494723370576
# 24.	 score=0.11368078250954117
# 25.	 score=0.11350834383710229
# 26.	 score=0.11013532796408665
# 27.	 score=0.10285061267937134
# 28.	 score=0.10089232921876579
# 29.	 score=0.10081836714712566
# 30.	 score=0.09828639911515769
# 31.	 score=0.09642326225202091
# 32.	 score=0.09612961145836985
# 33.	 score=0.08078612161488019
# 34.	 score=0.08069954152829983
# 35.	 score=0.0805379253666838
# 36.	 score=0.08046843929719794
# 37.	 score=0.07948453431329305
# 38.	 score=0.07937414470290305
# 39.	 score=0.07865913748789577
# 40.	 score=0.07825559658435521
# 41.	 score=0.07579477962353809
# 42.	 score=0.07565392048267894
# 43.	 score=0.07428540011415885
# 44.	 score=0.07351555884431771
# 45.	 score=0.07319954152830022
# 46.	 score=0.07047435005310865
# 47.	 score=0.06437919520795377
# 48.	 score=0.06361151844027702
# 49.	 score=0.06180970913846795
# Pivoting tables
#   0%|          | 0/1566674 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Collecting distances from 50
#   0%|          | 0/50 [00:00<?, ?it/s]
# Wall time: 5h 37min 39s

# %%
dist_np_df = pd.DataFrame(dist_np)
X = dist_np_df.drop(columns=[0]).values
y = dist_np_df[0].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, stratify=y, random_state=3)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                results['mean_test_score'][candidate],
                results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

from sklearn.model_selection import GridSearchCV
parameters = {'n_estimators': range(300, 2000, 300),
              'criterion':["entropy", "gini"],
              'max_depth': range(2, 30, 5)}

clf = GridSearchCV(RandomForestClassifier(n_jobs=12), parameters, cv=5, n_jobs=2, verbose=3, scoring="accuracy")

clf.fit(X_train, y_train)

report(clf.cv_results_, n_top=3)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Model with rank: 1
# Mean validation score: 0.903 (std: 0.014)
# Parameters: {'criterion': 'gini', 'max_depth': 17, 'n_estimators': 900}
#
# Model with rank: 2
# Mean validation score: 0.902 (std: 0.016)
# Parameters: {'criterion': 'gini', 'max_depth': 22, 'n_estimators': 1200}
#
# Model with rank: 2
# Mean validation score: 0.902 (std: 0.016)
# Parameters: {'criterion': 'gini', 'max_depth': 22, 'n_estimators': 1500}

# %%
rf = RandomForestClassifier(n_jobs=12, criterion='gini', max_depth= 15, n_estimators=400)#clf.best_estimator_

rf.fit(X_train, y_train)

from sklearn.metrics import classification_report

y_pred = rf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      private       0.84      0.87      0.86       173
#       public       0.88      0.85      0.86       186
#
#     accuracy                           0.86       359
#    macro avg       0.86      0.86      0.86       359
# weighted avg       0.86      0.86      0.86       359

# %%
from sklearn.metrics import accuracy_score, f1_score

print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average="weighted"))
# Out:
# 0.8607242339832869
# 0.8607696387132662
