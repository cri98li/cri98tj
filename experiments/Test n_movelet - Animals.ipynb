# %%
import geolib.geohash
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import pandas as pd
from tqdm.auto import tqdm
from cri98tj.partitioners.Geohash_partitioner import Geohash_partitioner
from cri98tj.normalizers.FirstPoint_normalizer import FirstPoint_normalizer
from cri98tj.selectors.RandomInformationGain_selector import RandomInformationGain_selector
from cri98tj.distancers.Euclidean_distancer import Euclidean_distancer
from sklearn.model_selection import train_test_split
from cri98tj.distancers.Euclidean_distancer import euclideanBestFitting

# %%
df_original = pd.read_csv('../examples/Animals Dataset/data/animals_preapred.zip').sort_values(by=["tid", "t"])
df_original = df_original[["tid", "class", "c1", "c2", "t"]]
df_original.head()
# Out:
#    tid class       c1       c2   t
# 0    1     D  50.1066  3.79665   0
# 1    1     D  50.1045  3.79455   4
# 2    1     D  50.1111  3.79845   7
# 3    1     D  50.1072  3.79845   9
# 4    1     D  50.1132  3.79965  15

# %%
tid_train, tid_test, _, _ = train_test_split(df_original.groupby(by=["tid"]).max().reset_index()["tid"],
                                                        df_original.groupby(by=["tid"]).max().reset_index()["class"],
                                                        test_size=.3,
                                                        stratify=df_original.groupby(by=["tid"]).max().reset_index()["class"],
                                                        random_state=3)

spatioTemporalCols = ["c1", "c2", "t"]
n_jobs = 24
verbose = False

# %%
import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score

def compute_measures(test, pred):
    return (accuracy_score(test, pred), precision_score(test, pred, average="micro"), f1_score(test, pred, average="micro"), recall_score(test, pred, average="micro"))

# %%
# %%time

from datetime import datetime
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score
from cri98tj.distancers.InterpolatedRootDistance_distancer import InterpolatedRootDistance_distancer, \
    InterpolatedRootDistanceBestFitting

precision = 2

res = []
n_mov_rig = []
time = []
for i in tqdm(range(2, 20)):
    df = df_original[["tid", "class", "c1", "c2", "t"]].copy()
    
    res.append((.0, .0, .0, .0, .0))
    n_mov_rig.append(0)
    time.append(.0)

    for _ in range(3):
        normalizer = FirstPoint_normalizer(spatioTemporalColumns=spatioTemporalCols, fillna=None, verbose=verbose)
        distancer = InterpolatedRootDistance_distancer(normalizer=normalizer, spatioTemporalColumns=spatioTemporalCols, n_jobs=n_jobs, verbose=verbose)
        partitioner = Geohash_partitioner(precision=precision, spatioTemporalColumns=spatioTemporalCols, verbose=verbose)

        start = datetime.now()
        part = partitioner.fit_transform(df[df.tid.isin(tid_train)].values)
        selector = RandomInformationGain_selector(top_k=int(1.4**i), bestFittingMeasure=InterpolatedRootDistanceBestFitting, movelets_per_class=None, trajectories_for_orderline=None, n_jobs=n_jobs, spatioTemporalColumns=spatioTemporalCols, normalizer=normalizer, verbose=verbose)
        shapelets = selector.fit_transform(part)
        _, dist_np = distancer.fit_transform((df.values, shapelets))
        stop = start - datetime.now()

        n_mov_rig[i-2] += (dist_np.shape[1])

        clf = RandomForestClassifier(max_depth=3, random_state=3, n_jobs=n_jobs, n_estimators=5000)

        dist_np_df = pd.DataFrame(dist_np)
        X = dist_np_df.drop(columns=[0]).values
        y = dist_np_df[0].values

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, stratify=y, random_state=3)

        clf.fit(X_train, y_train)

        y_pred = clf.predict(X_test)

        res[i-2] = tuple(a+b for a, b in zip(compute_measures(y_test, y_pred), res[i-2]))
        time[i-2] += stop.total_seconds()*1000 #millisecondi

    res[i-2] = list(map(lambda x: x/3, res[i-2]))
    n_mov_rig[i-2] /= 3
    time[i-2] /= 3
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# CPU times: user 7min 41s, sys: 1min 23s, total: 9min 5s
# Wall time: 29min 41s

# %%
df_res_rig = pd.DataFrame(res, columns=["acc", "prec", "f1", "recall"])

df_res_rig["t"] = time

df_res_rig.t *= -1

df_res_rig["n"] = n_mov_rig

df_res_rig.to_csv(f"Test n_movelet animals RIG {precision}.csv", index=None)

# %%
precision = 4

df_res_rig = pd.read_csv(f"Test n_movelet animals RIG {precision}.csv")

df_res_rig
# Out:
#          acc      prec        f1    recall           t      n
# 0   0.316129  0.316129  0.316129  0.316129  22300.6424    2.0
# 1   0.490323  0.490323  0.490323  0.490323  24325.7862    3.0
# 2   0.606452  0.606452  0.606452  0.606452  24646.3840    4.0
# 3   0.741935  0.741935  0.741935  0.741935  27821.2740    6.0
# 4   0.806452  0.806452  0.806452  0.806452  27863.3256    8.0
# 5   0.748387  0.748387  0.748387  0.748387  27946.1020   11.0
# 6   0.812903  0.812903  0.812903  0.812903  28597.8178   15.0
# 7   0.877419  0.877419  0.877419  0.877419  29347.0732   21.0
# 8   0.883871  0.883871  0.883871  0.883871  30171.6186   29.0
# 9   0.851613  0.851613  0.851613  0.851613  32568.5104   41.0
# 10  0.883871  0.883871  0.883871  0.883871  36065.7852   57.0
# 11  0.909677  0.909677  0.909677  0.909677  41664.4262   80.0
# 12  0.877419  0.877419  0.877419  0.877419  45874.6606  112.0
# 13  0.903226  0.903226  0.903226  0.903226  53452.3630  156.0
# 14  0.896774  0.896774  0.896774  0.896774  61001.7348  218.0
# 15  0.851613  0.851613  0.851613  0.851613  66995.4498  279.0
# 16  0.877419  0.877419  0.877419  0.877419  68670.1556  279.0
# 17  0.877419  0.877419  0.877419  0.877419  68863.9532  279.0

# %%
## Test con selezione random

# %%
# %%time
from cri98tj.selectors.Random_selector import Random_selector
from sklearn.metrics import accuracy_score
from cri98tj.distancers.InterpolatedRootDistance_distancer import InterpolatedRootDistance_distancer, \
    InterpolatedRootDistanceBestFitting
from datetime import datetime

res = []
n_mov_r = []
time = []
i=1
for n in tqdm(df_res_rig.n.unique()):
    df = df_original[["tid", "class", "c1", "c2", "t"]].copy()
    
    res.append((.0, .0, .0, .0, .0))
    n_mov_r.append(0)
    time.append(.0)
    
    c = 0
    
    while c < 3: 
        try:
            normalizer = FirstPoint_normalizer(spatioTemporalColumns=spatioTemporalCols, fillna=None, verbose=verbose)
            distancer = InterpolatedRootDistance_distancer(normalizer=normalizer, spatioTemporalColumns=spatioTemporalCols, n_jobs=n_jobs, verbose=verbose)
            partitioner = Geohash_partitioner(precision=precision, spatioTemporalColumns=spatioTemporalCols, verbose=verbose)

            start = datetime.now()
            part = partitioner.fit_transform(df[df.tid.isin(tid_train)].values)
            selector = Random_selector(movelets_per_class=max(1, n//6), n_jobs=n_jobs, spatioTemporalColumns=spatioTemporalCols, normalizer=normalizer, verbose=verbose)
            shapelets = selector.fit_transform(part)

            _, dist_np = distancer.fit_transform((df.values, shapelets))
            stop = start - datetime.now()

            n_mov_r[i-1] += (dist_np.shape[1])

            clf = RandomForestClassifier(max_depth=3, random_state=3, n_jobs=n_jobs, n_estimators=5000)

            dist_np_df = pd.DataFrame(dist_np)
            X = dist_np_df.drop(columns=[0]).values
            y = dist_np_df[0].values

            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, stratify=y, random_state=3)

            clf.fit(X_train, y_train)

            y_pred = clf.predict(X_test)

            res[i-1] = tuple(a+b for a, b in zip(compute_measures(y_test, y_pred), res[i-1]))
            time[i-1] += stop.total_seconds()*1000 #millisecondi

            c += 1
        except:
            print("failed")

    res[i-1] = list(map(lambda x: x/3, res[i-1]))
    n_mov_r[i-1] /= 3
    time[i-1] /= 3
    
    i +=1
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# CPU times: user 6min 14s, sys: 58.4 s, total: 7min 13s
# Wall time: 14min 49s

# %%
df_res_r = pd.DataFrame(res, columns=["acc", "prec", "f1", "recall"])

df_res_r["t"] = time

df_res_r.t *= -1

df_res_r["n"] = n_mov_r

df_res_r.to_csv(f"Test n_movelet animals R {precision}.csv", index=None)

# %%
df_res_r
# Out:
#          acc      prec        f1    recall             t      n
# 0   0.430108  0.430108  0.430108  0.430108   7081.353000    4.0
# 1   0.526882  0.526882  0.526882  0.526882   7201.945667    4.0
# 2   0.473118  0.473118  0.473118  0.473118   7191.734667    4.0
# 3   0.483871  0.483871  0.483871  0.483871   6355.536333    4.0
# 4   0.462366  0.462366  0.462366  0.462366   6075.208333    4.0
# 5   0.580645  0.580645  0.580645  0.580645   7393.053333    4.0
# 6   0.677419  0.677419  0.677419  0.677419   7504.184000    7.0
# 7   0.602151  0.602151  0.602151  0.602151   8290.274667   10.0
# 8   0.752688  0.752688  0.752688  0.752688   7891.199667   13.0
# 9   0.752688  0.752688  0.752688  0.752688   8930.935667   19.0
# 10  0.806452  0.806452  0.806452  0.806452   9784.145333   28.0
# 11  0.827957  0.827957  0.827957  0.827957  12107.083333   40.0
# 12  0.838710  0.838710  0.838710  0.838710  15254.782000   55.0
# 13  0.806452  0.806452  0.806452  0.806452  22265.846333   77.0
# 14  0.806452  0.806452  0.806452  0.806452  23063.274667   97.0
# 15  0.892473  0.892473  0.892473  0.892473  25051.737667  117.0

# %%
#voronoi

# %%
#r=600, ss=300/600 sd=10

# %%
# %%time
from cri98tj.selectors.Random_selector import Random_selector
from sklearn.metrics import accuracy_score
from cri98tj.distancers.InterpolatedRootDistance_distancer import InterpolatedRootDistance_distancer, \
    InterpolatedRootDistanceBestFitting
from datetime import datetime
from cri98tj.partitioners.Voronoi_partitioner import Voronoi_partitioner

res = []
n_mov_r = []
time = []
i=1
for n in tqdm(df_res_rig.n.unique()):
    df = df_original[["tid", "class", "c1", "c2", "t"]].copy()
    
    res.append((.0, .0, .0, .0, .0))
    n_mov_r.append(0)
    time.append(.0)
    
    
    for _ in range(3): 
        normalizer = FirstPoint_normalizer(spatioTemporalColumns=spatioTemporalCols, fillna=None, verbose=verbose)
        distancer = InterpolatedRootDistance_distancer(normalizer=normalizer, spatioTemporalColumns=spatioTemporalCols, n_jobs=n_jobs, verbose=verbose)
        partitioner = Voronoi_partitioner(spatioTemporalColumns=spatioTemporalCols, radius=600, stop_distance=10, stop_seconds=600)

        start = datetime.now()
        part = partitioner.fit_transform(df[df.tid.isin(tid_train)].values)
        selector = RandomInformationGain_selector(top_k=n, bestFittingMeasure=InterpolatedRootDistanceBestFitting, movelets_per_class=None, trajectories_for_orderline=None, n_jobs=n_jobs, spatioTemporalColumns=spatioTemporalCols, normalizer=normalizer, verbose=verbose)
        shapelets = selector.fit_transform(part)

        _, dist_np = distancer.fit_transform((df.values, shapelets))
        stop = start - datetime.now()

        n_mov_r[i-1] += (dist_np.shape[1])

        clf = RandomForestClassifier(max_depth=3, random_state=3, n_jobs=n_jobs, n_estimators=5000)

        dist_np_df = pd.DataFrame(dist_np)
        X = dist_np_df.drop(columns=[0]).values
        y = dist_np_df[0].values

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, stratify=y, random_state=3)

        clf.fit(X_train, y_train)

        y_pred = clf.predict(X_test)

        res[i-1] = tuple(a+b for a, b in zip(compute_measures(y_test, y_pred), res[i-1]))
        time[i-1] += stop.total_seconds()*1000 #millisecondi


    res[i-1] = list(map(lambda x: x/3, res[i-1]))
    n_mov_r[i-1] /= 3
    time[i-1] /= 3
    
    i +=1
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:19:56,442  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         50 12:19:56,492  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         51 12:19:56,493  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        109 12:19:56,551  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:21:07,615  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:21:07,664  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 12:21:07,665  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        106 12:21:07,721  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:22:19,410  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         54 12:22:19,464  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         55 12:22:19,465  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        117 12:22:19,527  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:23:29,726  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         50 12:23:29,776  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         51 12:23:29,777  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        106 12:23:29,832  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:24:39,484  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         51 12:24:39,535  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         53 12:24:39,537  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        107 12:24:39,591  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:25:52,962  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         51 12:25:53,013  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         53 12:25:53,015  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        106 12:25:53,068  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:27:05,754  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:27:05,803  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 12:27:05,804  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        105 12:27:05,859  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:28:19,004  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:28:19,053  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         54 12:28:19,058  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        106 12:28:19,110  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:29:30,072  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:29:30,120  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:29:30,121  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:29:30,175  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:30:40,873  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:30:40,922  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 12:30:40,923  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        106 12:30:40,979  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:31:53,038  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:31:53,086  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:31:53,087  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:31:53,141  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:33:04,147  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:33:04,195  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:33:04,196  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        104 12:33:04,251  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:34:15,911  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:34:15,959  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:34:15,960  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:34:16,014  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:35:28,698  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         47 12:35:28,745  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         48 12:35:28,746  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        102 12:35:28,800  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:36:41,507  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         53 12:36:41,560  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         59 12:36:41,566  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        118 12:36:41,625  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:37:54,828  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         53 12:37:54,881  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         55 12:37:54,883  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        117 12:37:54,945  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:39:07,805  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:39:07,853  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:39:07,854  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:39:07,908  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:40:21,014  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:40:21,062  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:40:21,063  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:40:21,117  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:41:33,083  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         54 12:41:33,137  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         56 12:41:33,139  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        116 12:41:33,199  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:42:46,561  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         54 12:42:46,615  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         55 12:42:46,616  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        116 12:42:46,677  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:43:59,860  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:43:59,909  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         51 12:43:59,911  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        118 12:43:59,978  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:45:11,305  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:45:11,354  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 12:45:11,355  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        104 12:45:11,409  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:46:23,836  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         47 12:46:23,883  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         48 12:46:23,884  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        101 12:46:23,937  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:47:35,386  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:47:35,435  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         51 12:47:35,437  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        110 12:47:35,496  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:48:47,032  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         47 12:48:47,079  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         48 12:48:47,080  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        101 12:48:47,133  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:49:58,747  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:49:58,795  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:49:58,796  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:49:58,850  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:51:11,211  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:51:11,259  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:51:11,260  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:51:11,314  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:52:23,707  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:52:23,755  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:52:23,756  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        102 12:52:23,809  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:53:35,672  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         52 12:53:35,724  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         53 12:53:35,725  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        112 12:53:35,784  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:54:49,570  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         51 12:54:49,621  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         56 12:54:49,626  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        107 12:54:49,677  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:56:03,945  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         52 12:56:03,997  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         53 12:56:03,998  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        112 12:56:04,057  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:57:17,778  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:57:17,826  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         53 12:57:17,831  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 12:57:17,881  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:58:31,470  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 12:58:31,519  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 12:58:31,520  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        104 12:58:31,574  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 12:59:45,987  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 12:59:46,035  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 12:59:46,036  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        102 12:59:46,089  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:01:00,903  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         52 13:01:00,955  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         53 13:01:00,956  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        113 13:01:01,016  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:02:15,802  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         50 13:02:15,852  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         52 13:02:15,854  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        114 13:02:15,916  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:03:31,066  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 13:03:31,114  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 13:03:31,115  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 13:03:31,169  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          1 13:04:48,300  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 13:04:48,348  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 13:04:48,349  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        105 13:04:48,404  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:06:04,485  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 13:06:04,533  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 13:06:04,534  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        106 13:06:04,591  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:07:19,309  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 13:07:19,357  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 13:07:19,358  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        102 13:07:19,411  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:08:36,281  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         51 13:08:36,332  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         53 13:08:36,334  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        112 13:08:36,393  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:09:54,238  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 13:09:54,286  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 13:09:54,287  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        104 13:09:54,342  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:11:12,695  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 13:11:12,744  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 13:11:12,745  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        104 13:11:12,799  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:12:34,230  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 13:12:34,279  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 13:12:34,280  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        109 13:12:34,339  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:13:55,406  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 13:13:55,455  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 13:13:55,456  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        111 13:13:55,517  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:15:19,519  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         48 13:15:19,567  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         49 13:15:19,568  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        105 13:15:19,624  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:16:44,038  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 13:16:44,087  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 13:16:44,088  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        103 13:16:44,141  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# Executing command: cat tmp/gps.csv | sort -t',' -k1 -k2 -k3 -k9 -m | gzip -c > tmp/gps_sorted.csv.gz
# Executing command: java -Xmx2048M -jar octo_processor.jar -app spacetime_reconstruct -i tmp/gps_sorted.csv.gz -o tmp/gps_600_50.csv.gz -ds 10 -dt 600
# Executing command: java -Xmx2048M -jar octo_processor.jar -app point_aggregate -i tmp/gps_600_50.csv.gz -o tmp/gps_edgelist_200.csv.gz -r 600
#          0 13:18:08,238  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:52) - Starting clustering of points
#         49 13:18:08,287  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:65) - Processed 10000 points
#         50 13:18:08,288  INFO (ExtractDelaunayFromTrajectoryPoints.java:parseSource:71) - Export voronoi diagram
# ShapeFileWriter: start mixed-geom-test
#        105 13:18:08,343  INFO (ExtractDelaunayFromTrajectoryPoints.java:prepareNext:141) - found 677 edges
# CPU times: user 16min 37s, sys: 1min 35s, total: 18min 12s
# Wall time: 59min 38s

# %%
df_res_rig_v = pd.DataFrame(res, columns=["acc", "prec", "f1", "recall"])

df_res_rig_v["t"] = time

df_res_rig_v.t *= -1

df_res_rig_v["n"] = n_mov_r

df_res_rig_v.to_csv(f"Test n_movelet animals RIG voronoi.csv", index=None)

# %%
df_res_rig_v

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=n_mov_r, y=acc_r, mode='lines', name='Random selector'))
fig.add_trace(go.Scatter(x=n_mov_rig, y=acc_rig, mode='lines', name='Random info gain selector'))

fig.show()
