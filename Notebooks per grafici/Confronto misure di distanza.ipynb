# %%
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import math
from datetime import timedelta, datetime
import plotly.express as px
from geolib import geohash

# %%
df_animals_euclidea = pd.read_csv("../experiments/Test euclidea animals.csv")
df_animals_IRD = pd.read_csv("../experiments/Test IRD animals.csv")
df_animals_DTW = pd.read_csv("../experiments/Test DTW animals.csv")

# %%
plt.plot(df_animals_euclidea.precision, df_animals_euclidea.acc, '-o', label="ED")
plt.plot(df_animals_IRD.precision, df_animals_IRD.acc, '-^', label="IRD")
plt.plot(df_animals_DTW.precision, df_animals_DTW.acc, '-s', label="DTW")

plt.legend()

plt.legend(fontsize=20, frameon=False, ncol=1, handleheight=0.3, 
           handlelength=1, columnspacing=.5, handletextpad=.3)
plt.ylim(ymin=0, ymax=1)
#plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(5.5, 4)
fig.set_dpi(300)

plt.xlabel("precision", fontsize=22)
plt.ylabel("accuracy", fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22)

plt.title("animals", fontsize=24)

plt.xticks(np.arange(3, 7+1, 1))


plt.savefig("animals distance.pdf", bbox_inches='tight')

plt.show()

# %%
plt.plot(df_animals_euclidea.precision, df_animals_euclidea.t/1000, '-o', label="ED")
plt.plot(df_animals_IRD.precision, df_animals_IRD.t/1000, '-^', label="IRD")
plt.plot(df_animals_DTW.precision, df_animals_DTW.t/1000, '-s', label="DTW")

ax = plt.gca()
#ax.set_yscale('log')


plt.legend(fontsize=20, frameon=False, ncol=3, handleheight=0.3, 
           handlelength=1, columnspacing=.5, handletextpad=.3)
plt.yscale('log')
fig = plt.gcf()
plt.ylim(ymin=8, ymax=10**4)
fig.set_size_inches(5.5, 4)
fig.set_dpi(300)
plt.tick_params(axis='both', which='major', labelsize=20)

plt.xlabel("precision", fontsize=22)
plt.ylabel("runtime", fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22)

plt.title("animals", fontsize=24)

plt.xticks(np.arange(3, 7+1, 1))

plt.savefig("animals distance time.pdf", bbox_inches='tight')

plt.show()

# %%
df_vehicles_euclidea = pd.read_csv("../experiments/Test euclidea vehicles.csv")
df_vehicles_IRD = pd.read_csv("../experiments/Test IRD vehicles.csv")
df_vehicles_DTW = pd.read_csv("../experiments/Test DTW vehicles.csv")

# %%
plt.plot(df_vehicles_euclidea.precision[2:], df_vehicles_euclidea.acc[2:], '-o', label="ED")
plt.plot(df_vehicles_IRD.precision[2:], df_vehicles_IRD.acc[2:], '-^', label="IRD")
plt.plot(df_vehicles_DTW.precision[:-1], df_vehicles_DTW.acc[:-1], '-s', label="DTW")


#plt.legend(fontsize=16, frameon=False)
plt.ylim(ymin=0, ymax=1)
#plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(5.5, 4)
fig.set_dpi(300)
plt.xlabel("precision", fontsize=22)
plt.ylabel("accuracy", fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks([5, 6, 7])

plt.title("vehicles", fontsize=24)

plt.savefig("vehicles distance.pdf", bbox_inches='tight')

plt.show()

# %%
plt.plot(df_vehicles_euclidea.precision[2:], df_vehicles_euclidea.t[2:]/1000, '-o', label="ED")
plt.plot(df_vehicles_IRD.precision[2:], df_vehicles_IRD.t[2:]/1000, '-^', label="IRD")
plt.plot(df_vehicles_DTW.precision[:-1], df_vehicles_DTW.t[:-1]/1000, '-s', label="DTW")


ax = plt.gca()
ax.set_yscale('log')


#plt.legend(fontsize=16, frameon=False)
plt.ylim(ymin=10, ymax=10**4)
#plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(5.5, 4)
fig.set_dpi(300)
plt.xlabel("precision", fontsize=22)
plt.ylabel("runtime", fontsize=22)
plt.xticks([5, 6, 7])
plt.tick_params(axis='both', which='major', labelsize=22)

plt.title("vehicles", fontsize=24)

plt.savefig("vehicles distance time.pdf", bbox_inches='tight')

plt.show()
