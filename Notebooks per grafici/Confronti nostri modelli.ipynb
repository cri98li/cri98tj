# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# !ls ../experiments/*.csv
# Out:
# "ls" non Š riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.

# %% [markdown]
# ## Animals

# %%
nMov_RIG3 = pd.read_csv("../experiments/Test n_movelet animals RIG 3.csv")
nMov_RIG4 = pd.read_csv("../experiments/Test n_movelet animals RIG 4.csv")
nMov_RIG5 = pd.read_csv("../experiments/Test n_movelet animals RIG 5.csv")
nMov_RIG6 = pd.read_csv("../experiments/Test n_movelet animals RIG 6.csv")
nMov_RIG7 = pd.read_csv("../experiments/Test n_movelet animals RIG 7.csv")

# %%
nMov_RIG3.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#             acc      prec        f1    recall            t         n
# count  18.00000  18.00000  18.00000  18.00000     18.00000  18.00000
# mean    0.86858   0.86858   0.86858   0.86858  25224.42480  37.38889
# std     0.09429   0.09429   0.09429   0.09429   7905.87446  28.58658
# min     0.62366   0.62366   0.62366   0.62366  15334.01400   2.00000
# 25%     0.84140   0.84140   0.84140   0.84140  17410.49975   8.75000
# 50%     0.91398   0.91398   0.91398   0.91398  24534.81600  35.00000
# 75%     0.92473   0.92473   0.92473   0.92473  33607.21233  68.00000
# max     0.93548   0.93548   0.93548   0.93548  34341.41100  68.00000

# %%
plt.plot(nMov_RIG3.n[:-6], nMov_RIG3.acc[:-6], label="precision 3")
plt.plot(nMov_RIG4.n[:-2], nMov_RIG4.acc[:-2], label="precision 4")
plt.plot(nMov_RIG5.n, nMov_RIG5.acc, label="precision 5")
plt.plot(nMov_RIG6.n, nMov_RIG6.acc, label="precision 6")
plt.plot(nMov_RIG7.n, nMov_RIG7.acc, label="precision 7")



plt.legend()

plt.legend()
plt.ylim(ymin=0, ymax=1)
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(4.5, 3)
fig.set_dpi(300)

plt.xlabel('Number of shapelets', fontsize=12) 
plt.ylabel('Accuracy', fontsize=12) 
plt.tick_params(axis='both', which='major', labelsize=12)

plt.savefig("Animals RIG.pdf", bbox_inches='tight')

plt.show()

# %%
nMov_R3 = pd.read_csv("../experiments/Test n_movelet animals R 3.csv")
nMov_R4 = pd.read_csv("../experiments/Test n_movelet animals R 4.csv")
nMov_R5 = pd.read_csv("../experiments/Test n_movelet animals R 5.csv")
nMov_R6 = pd.read_csv("../experiments/Test n_movelet animals R 6.csv")
nMov_R7 = pd.read_csv("../experiments/Test n_movelet animals R 7.csv")

# %%
plt.plot(nMov_R3.n, nMov_R3.acc, label="precision 3")
plt.plot(nMov_R4.n, nMov_R4.acc, label="precision 4")
plt.plot(nMov_R5.n, nMov_R5.acc, label="precision 5")
plt.plot(nMov_R6.n, nMov_R6.acc, label="precision 6")
plt.plot(nMov_R7.n, nMov_R7.acc, label="precision 7")


plt.legend()

plt.legend()
plt.ylim(ymin=0, ymax=1)
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(4.5, 3)
fig.set_dpi(300)

plt.xlabel('Number of shapelets', fontsize=12) 
plt.ylabel('Accuracy', fontsize=12) 
plt.tick_params(axis='both', which='major', labelsize=12)

plt.savefig("Animals R.pdf", bbox_inches='tight')

plt.show()

# %%
nMov_R4
# Out:
#          acc      prec        f1    recall             t      n
# 0   0.430108  0.430108  0.430108  0.430108   7081.353000    4.0
# 1   0.526882  0.526882  0.526882  0.526882   7201.945667    4.0
# 2   0.473118  0.473118  0.473118  0.473118   7191.734667    4.0
# 3   0.483871  0.483871  0.483871  0.483871   6355.536333    4.0
# 4   0.462366  0.462366  0.462366  0.462366   6075.208333    4.0
# 5   0.580645  0.580645  0.580645  0.580645   7393.053333    4.0
# 6   0.677419  0.677419  0.677419  0.677419   7504.184000    7.0
# 7   0.602151  0.602151  0.602151  0.602151   8290.274667   10.0
# 8   0.752688  0.752688  0.752688  0.752688   7891.199667   13.0
# 9   0.752688  0.752688  0.752688  0.752688   8930.935667   19.0
# 10  0.806452  0.806452  0.806452  0.806452   9784.145333   28.0
# 11  0.827957  0.827957  0.827957  0.827957  12107.083333   40.0
# 12  0.838710  0.838710  0.838710  0.838710  15254.782000   55.0
# 13  0.806452  0.806452  0.806452  0.806452  22265.846333   77.0
# ...

# %% [markdown]
# ## Vehicles

# %%
nMov_RIG5 = pd.read_csv("../experiments/Test n_movelet vehicle RIG 5.csv")
nMov_RIG6 = pd.read_csv("../experiments/Test n_movelet vehicle RIG 6.csv")
nMov_RIG7 = pd.read_csv("../experiments/Test n_movelet vehicle RIG 7.csv")

# %%
plt.plot(nMov_RIG5.n[:-2], nMov_RIG5.acc[:-2]*5/3, label="precision 5")
plt.plot(nMov_RIG6.n[:-2], nMov_RIG6.acc[:-2]*5/3, label="precision 6")
plt.plot(nMov_RIG7.n[:-2], nMov_RIG7.acc[:-2]*5/3, label="precision 7")


plt.legend()
plt.ylim(ymin=0, ymax=1)
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(4.5, 3)
plt.xlabel('Number of shapelets', fontsize=12) 
plt.ylabel('Accuracy', fontsize=12) 
plt.tick_params(axis='both', which='major', labelsize=12)
fig.set_dpi(300)
plt.savefig("Vehicle RIG.pdf", bbox_inches='tight')



plt.show()

# %%
nMov_R5 = pd.read_csv("../experiments/Test n_movelet vehicle R 5.csv")
nMov_R6 = pd.read_csv("../experiments/Test n_movelet vehicle R 6.csv")
nMov_R7 = pd.read_csv("../experiments/Test n_movelet vehicle R 7.csv")

# %%
plt.plot(nMov_R5.n, nMov_R5.acc, label="precision 5")
plt.plot(nMov_R6.n, nMov_R6.acc, label="precision 6")
plt.plot(nMov_R7.n, nMov_R7.acc, label="precision 7")

plt.legend()
plt.ylim(ymin=0, ymax=1)
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(4.5, 3)
fig.set_dpi(300)
plt.xlabel('Number of shapelets', fontsize=12) 
plt.ylabel('Accuracy', fontsize=12) 
plt.tick_params(axis='both', which='major', labelsize=12)
plt.savefig("Vehicle R.pdf", bbox_inches='tight')



plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from tslearn.generators import random_walks
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.piecewise import PiecewiseAggregateApproximation
from tslearn.piecewise import SymbolicAggregateApproximation, \
    OneD_SymbolicAggregateApproximation

numpy.random.seed(32)
# Generate a random walk time series
n_ts, sz, d = 1, 50, 1
dataset = random_walks(n_ts=n_ts, sz=sz, d=d)
scaler = TimeSeriesScalerMeanVariance(mu=0., std=1.)  # Rescale time series
dataset = scaler.fit_transform(dataset)

# PAA transform (and inverse transform) of the data
n_paa_segments = 12
paa = PiecewiseAggregateApproximation(n_segments=n_paa_segments)
paa_dataset_inv = paa.inverse_transform(paa.fit_transform(dataset))

# SAX transform
n_sax_symbols = 5
sax = SymbolicAggregateApproximation(n_segments=n_paa_segments,
                                     alphabet_size_avg=n_sax_symbols)
sax_dataset_inv = sax.inverse_transform(sax.fit_transform(dataset))

plt.figure()
plt.subplot(1, 3, 1)  # First, raw time series
plt.plot(dataset[0].ravel(), "b-")
plt.title("Raw time series", fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('time (s)', fontsize=20)
plt.ylabel('value', fontsize=20)

plt.subplot(1, 3, 2)  # Second, PAA
plt.plot(dataset[0].ravel(), "b-", alpha=0.2)
plt.plot(paa_dataset_inv[0].ravel(), "b-")
plt.title(f"PAA, 12 segments", fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('time (s)', fontsize=20)
plt.ylabel('value', fontsize=20)

plt.subplot(1, 3, 3)  # Then SAX
plt.plot(dataset[0].ravel(), "b-", alpha=0.2)
plt.plot(sax_dataset_inv[0].ravel(), "b-")
plt.title("SAX, %d symbols" % n_sax_symbols, fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('time (s)', fontsize=20)
plt.ylabel('value', fontsize=20)

fig = plt.gcf()
fig.set_size_inches(18, 6)

fig.set_dpi(200)

plt.tight_layout()

plt.savefig('ts approx.pdf', bbox_inches='tight')

plt.show()

# %%
sax.fit_transform(dataset)
# Out:
# array([[[0],
#         [0],
#         [0],
#         [2],
#         [3],
#         [3],
#         [3],
#         [3],
#         [4],
#         [4],
#         [4],
#         [2]]])

# %%
# !ls ../experiments/*.csv
# Out:
# "ls" non Š riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.

# %% [markdown]
# ## Confronto +dim Animals

# %%
nMov_RIG3 = pd.read_csv("../experiments/Test n_movelet animals RIG 3.csv")
nMov_RIG1_2 = pd.read_csv("../experiments/Test n_movelet animals RIG 1-2.csv")
nMov_RIG2_3 = pd.read_csv("../experiments/Test n_movelet animals RIG 2-3.csv")
nMov_RIG3_4 = pd.read_csv("../experiments/Test n_movelet animals RIG 3-4.csv")

# %%
#plt.plot(nMov_RIG1_2.n[:-4], nMov_RIG1_2.acc[:-4], label="precision 1-2")
plt.plot(nMov_RIG2_3.n[:-3], nMov_RIG2_3.t[:-3]/60000, label="precision 2-3")
plt.plot(nMov_RIG3_4.n[:-1], nMov_RIG3_4.t[:-1]/60000, label="precision 3-4")
plt.plot(nMov_RIG3.n[:-6], nMov_RIG3.t[:-6]/60000, label="precision 3")

plt.ylabel("time (min)")

plt.legend()
plt.ylim(ymin=0)
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(5.5, 4)
fig.set_dpi(300)
plt.savefig("Animals RIG +dim time.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Confronto +dim Vehicles

# %%
nMov_RIG6 = pd.read_csv("../experiments/Test n_movelet vehicle RIG 6.csv")
nMov_RIG6_7 = pd.read_csv("../experiments/Test n_movelet vehicle RIG 6-7.csv")
nMov_RIG5_6 = pd.read_csv("../experiments/Test n_movelet vehicle RIG 5-6.csv")

# %%
plt.plot(nMov_RIG5_6.n, nMov_RIG5_6.t/60000, label="precision 5-6")
plt.plot(nMov_RIG6_7.n, nMov_RIG6_7.t/60000, label="precision 6-7")
plt.plot(nMov_RIG6.n[:-2], nMov_RIG6.t[:-2]*5/3 /60000, label="precision 3")

plt.legend()

plt.ylabel("time (min)")

plt.legend()
plt.ylim(ymin=0)
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(5.5, 4)
fig.set_dpi(300)
plt.savefig("Vehicles RIG +dim time.pdf", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## MrSQM

# %%
MrSQM_Animals = pd.read_csv("../Other classificators prototypes/mrsqm/example/"+
                           "Test MrSQM Animals.csv")

MrSQM_Vehicles = pd.read_csv("../Other classificators prototypes/mrsqm/example/"+
                           "Test MrSQM Vehicles.csv")

# %%
ax1 = plt.subplot()
plt.ylim(ymin=0)
plt.tick_params(axis='both', which='major', labelsize=18)
ax2 = plt.twinx()

l1 = ax1.plot(MrSQM_Animals.n, MrSQM_Animals.acc)
l2 = ax2.plot(MrSQM_Animals.n, MrSQM_Animals.t/60000, 'green')#min


ax1.set_ylabel('accuracy', color='blue', fontsize=18) 
ax2.set_ylabel('time (minutes)', color='green', fontsize=18) 

ax1.set_xlabel('#random configurations', fontsize=18) 
plt.tick_params(axis='both', which='major', labelsize=18)

#plt.legend([l1, l2], ["accuracy", "time"])
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(6.5, 5)
fig.set_dpi(300)
plt.savefig("MrSQM Animals.pdf", bbox_inches='tight')

plt.show()

# %%
ax1 = plt.subplot()
plt.ylim(ymin=0)
plt.tick_params(axis='both', which='major', labelsize=18)
ax2 = plt.twinx()

l1 = ax1.plot(MrSQM_Vehicles.n, MrSQM_Vehicles.acc)
l2 = ax2.plot(MrSQM_Vehicles.n, MrSQM_Vehicles.t/60000, 'green')#min


ax1.set_ylabel('accuracy', color='blue', fontsize=18) 
ax2.set_ylabel('time (minutes)', color='green', fontsize=18) 

ax1.set_xlabel('#random configurations', fontsize=18) 
plt.tick_params(axis='both', which='major', labelsize=18)

#plt.legend([l1, l2], ["accuracy", "time"])
plt.xlim(xmin=0)
fig = plt.gcf()
fig.set_size_inches(6.5, 5)
fig.set_dpi(300)
plt.savefig("MrSQM Vehicles.pdf", bbox_inches='tight')

plt.show()
